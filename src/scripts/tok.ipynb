# %%
from transformers import AutoTokenizer

tok = AutoTokenizer.from_pretrained("/home/ubuntu/OLMo-core/tokenizer", trust_remote_code=True)

# %%
BEGIN_TEXT = "<|begin_of_text|>"
END_TEXT = "<|end_of_text|>"
IM_START_USER = "<|im_start|>user\n"
IM_START_ASSISTANT = "<|im_start|>assistant\n"
IM_END = "<|im_end|>\n"
THINK_START = "<|think_start|>\n"
THINK_END = "<|think_end|>\n"

# %%
out = tok.encode(THINK_START, add_special_tokens=False)
out
# Out:
# [45720, 62583, 66, 7095, 31147, 189]
